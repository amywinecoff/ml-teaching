# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
plt.style.use('ggplot')


plt.rc('font', size=20)
plt.rcParams["figure.autolayout"] = True

# %%
spirits = [['El Buho Espadin', 3, 0],
            ['Casamigos Reposado', 1, 1],
            ['Espolon Anejo',1.5, 2], 
            ['Laphroaig 12', 7, 4],
            ['Macallan 12', 5, 4],
            ['Knob Creek Bourbon', 4, 5]]

spirits_df = pd.DataFrame(spirits, columns=['spirit','smokiness', 'color' ])

spirits_df.head(10)
# Out:
#                spirit  smokiness  color
# 0     El Buho Espadin        3.0      0
# 1  Casamigos Reposado        1.0      1
# 2       Espolon Anejo        1.5      2
# 3        Laphroaig 12        7.0      4
# 4         Macallan 12        5.0      4
# 5  Knob Creek Bourbon        4.0      5

# %%
for i, label in enumerate(spirits_df['spirit']):
    print(label)
    print(spirits_df.loc[i, 'smokiness'])
    #print(label, spirits_df.loc[i, 'spirit'])
# Out:
# El Buho Espadin
# 3.0
# Casamigos Reposado
# 1.0
# Espolon Anejo
# 1.5
# Laphroaig 12
# 7.0
# Macallan 12
# 5.0
# Knob Creek Bourbon
# 4.0

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15, 10)
sns.scatterplot(y=spirits_df['smokiness'], x=spirits_df['color'], s=50)
plt.xlim([0, 7])
plt.ylim([0,7.5])


#sns.scatterplot(data=df,x=’G’,y=’GA’)

for i in range(spirits_df.shape[0]):
    plt.text(x=spirits_df['color'][i]+.1,
             y=spirits_df['smokiness'][i]+.1, 
             s=spirits_df['spirit'][i], 
             fontdict=dict(color='blue',size=14),
             bbox=dict(facecolor='yellow',alpha=0.5))
    
    
#     plt.text(x=df.G[i]+0.3,y=df.GA[i]+0.3,s=df.Team[i], 
#         fontdict=dict(color=’red’,size=10),
#         bbox=dict(facecolor=’yellow’,alpha=0.5))

# for i, label in enumerate(spirits_df['spirit']):
#     plt.annotate(label, spirits_df.loc[i, 'color'], spirits_df.loc[i, 'smokiness'])

plt.show()

# %%
x = [1,3]
y = [30,50]

fig, ax = plt.subplots()
sns.scatterplot(y=y, x=x, s=50)

ax.set_xlim(0, 5)
ax.set_ylim(10, 80)

ax.set_xlabel('x')
ax.set_ylabel('y')
